# %%
pip install yfinance
# Out:
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=0152dcce69672b84a553c4cf2c76a73afe7a6b5cd0e60ce22c910d2a92959a2f
#   Stored in directory: /Users/aliait/Library/Caches/pip/wheels/f2/b5/2c/59ba95dcf854e542944c75fe3da584e4e3833b319735a0546c
# Successfully built multitasking
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
## APD', 'APH', 'RACE', 'TEL', 'IFF', 'GLW'

# %%
apd = yf.Ticker("APD")

# %%
apd.dividends
# Out:
# Date
# 1983-06-29    0.028908
# 1983-09-29    0.028908
# 1983-12-29    0.028908
# 1984-03-30    0.028908
# 1984-06-28    0.028908
#                 ...
# 2021-03-31    1.500000
# 2021-06-30    1.500000
# 2021-09-30    1.500000
# 2021-12-31    1.500000
# 2022-03-31    1.620000
# Name: Dividends, Length: 155, dtype: float64

# %%
apd.financials
# Out:
#                                            2021-09-30    2020-09-30  \
# Research Development                       93500000.0    83900000.0
# Effect Of Accounting Charges                     None          None
# Income Before Tax                        2507400000.0  2423800000.0
# Minority Interest                         548300000.0   363300000.0
# Net Income                               2099100000.0  1886700000.0
# Selling General Administrative            744600000.0   731000000.0
# Gross Profit                             3136900000.0  2998200000.0
# Ebit                                     2354400000.0  2247200000.0
# Operating Income                         2354400000.0  2247200000.0
# Other Operating Expenses                  -55600000.0   -63900000.0
# Interest Expense                         -141800000.0  -109300000.0
# Extraordinary Items                              None          None
# Non Recurring                                    None          None
# ...

# %%
apd.recommendations
# Out:
#                                   Firm        To Grade  From Grade Action
# Date
# 2012-03-20 06:07:00     Morgan Stanley     Underweight               init
# 2012-03-27 09:19:00          Jefferies             Buy               main
# 2012-04-25 07:21:00          JP Morgan         Neutral               main
# 2012-04-26 06:09:00     Morgan Stanley    Equal-Weight                 up
# 2012-04-27 06:08:00          Citigroup         Neutral               down
# ...                                ...             ...         ...    ...
# 2022-02-07 12:13:36  B of A Securities         Neutral         Buy   down
# 2022-02-07 12:14:46        Wells Fargo      Overweight               main
# 2022-02-07 12:21:33      Deutsche Bank             Buy               main
# 2022-02-08 11:25:11        BMO Capital  Market Perform  Outperform   down
# 2022-03-21 10:11:17          JP Morgan      Overweight     Neutral     up
#
# [180 rows x 4 columns]

# %%
apd.calendar
# Out:
#                                 Value
# Earnings Date     2022-05-05 12:30:00
# Earnings Average                 2.36
# Earnings Low                     2.27
# Earnings High                    2.45
# Revenue Average            2969160000
# Revenue Low                2843000000
# Revenue High               3199000000

# %%
apd.news
# Out:
# [{'uuid': 'fbfb51ba-8c0b-3741-9120-0bbb4fa568cb',
#   'title': 'Can Air Products and Chemicals (APD) Keep the Earnings Surprise Streak Alive?',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/air-products-chemicals-apd-keep-161004902.html',
#   'providerPublishTime': 1649952604,
#   'type': 'STORY'},
#  {'uuid': '45a42c23-b589-3d95-9b6e-18955ed7671a',
#   'title': "Air Products (APD) Buys Air Liquide's Gas Units in UAE & Bahrain",
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/air-products-apd-buys-air-151703034.html',
#   'providerPublishTime': 1649949423,
#   'type': 'STORY'},
#  {'uuid': '0e2a2635-616c-3cda-8c5b-3c499778f9a6',
#   'title': 'Saudi Arabia Looks To Position NEOM As A Hydrogen Leader',
#   'publisher': 'Oilprice.com',
#   'link': 'https://finance.yahoo.com/news/saudi-arabia-looks-position-neom-200000240.html',
#   'providerPublishTime': 1649793600,
#   'type': 'STORY'},
#  {'uuid': '111448d3-d106-3a72-a69b-00d7a3c862d0',
# ...
